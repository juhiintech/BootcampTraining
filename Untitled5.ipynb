# %% [markdown]
# <a href="https://colab.research.google.com/github/juhiintech/BootcampTraining/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# machine learning improves by measuring error and correcting itself step by step.

# %%
# features
# labels
# prediction problem
# conclusion from visible data.

# %%
# Feature	gdpPercap
# Label	lifeExp
# Problem Type	Regression
# Goal	GDP se Life Expectancy predict karna
# Relationship	Positive Correlation (GDP ↑ → Life Expectancy ↑)

# %%
# Feature (Input Variable) → gdpPercap
# Label (Output Variable / Target) → lifeExp

# %%
# 1. Feature

# A feature is an input variable used by a machine learning model to make predictions.

# Example: GDP per capita, Marks, Attendance

# %%
# 2. Label (Target)

# A label is the output variable that the model tries to predict.

# Example: Life Expectancy, Result (Pass/Fail)

# %%
# 3. Epoch

# An epoch is one complete pass of the entire training dataset through the model.

# Example: Agar 100 images ko ek baar train kiya gaya, to 1 epoch hua.

# %%
# 4. Batch Size

# Batch size is the number of training samples processed before the model updates its weights.

# Example: 100 images aur batch size 10 ⇒ 10 batches per epoch.

# %%
# 5. Learning Rate

# Learning rate is a hyperparameter that controls how much the model updates its weights during training.

# Example: High learning rate = fast learning, Low learning rate = slow learning.

# %%
# 6. Feature Extraction

# Feature extraction is the process of extracting important information from raw data for model training.

# Example: Image se eyes, ears, shape identify karna.

# %%
# 7. Prediction Problem

# A prediction problem is a task where a model learns from data to predict an unknown output.

# Example: GDP se Life Expectancy predict karna.

# %%
# 8. Regression

# Regression is a machine learning problem where the output is a continuous numerical value.

# Example: House Price Prediction, Life Expectancy Prediction.

# %%
# 9. Classification

# Classification is a machine learning problem where the output belongs to predefined categories.

# Example: Cat/Dog, Spam/Not Spam, Pass/Fail.

# %%
# 10. Training Data

# Training data is the dataset used to teach a machine learning model.

# %%
# 11. Model

# A model is a program that learns patterns from data and makes predictions.

# %%
# Teachable Machine is primarily used for Classification Problems,
# where the model predicts categories such as Cat/Dog, Mask/No Mask,
# or different poses and sounds. It is generally not used for Regression Problems
# that predict continuous numerical values.

# %%
# Face unlock
# predicting land price
# google photos use what to define faces
# weather forecast

# %%
# Regression:

# A machine learning problem in which the output is a continuous numerical value.

# %%
# Classification:

# A machine learning problem in which the output belongs to one of the predefined categories or classes.

# %%
# Training Data

# Training data is the dataset used to train a machine learning model.

# The model learns patterns, relationships, and rules from the training data.

# Example:
# If we want to build a Cat vs Dog classifier:

# 800 images are used for training.
# The model learns the features of cats and dogs from these images.

# Purpose: To teach the model.

# %%
# Testing Data

# Testing data is the dataset used to evaluate the performance of a trained machine learning model.

# The testing data is new and unseen by the model during training.

# Example:

# 200 new images are used for testing.
# The model predicts whether each image is a cat or a dog.
# We then measure the model's accuracy.

# Purpose: To check how well the model performs on new data.

# %%
# Overfitting

# Overfitting occurs when a model learns the training data too well,
# including noise and unnecessary details, and performs poorly on new data.

# %%
# Underfitting

# Underfitting occurs when a model fails to learn the important patterns in the training data and
# performs poorly on both training and testing data.
